# %%
import pandas as pd

# %%
df = pd.read_csv("/config/workspace/artifact/02122023__113005/data_ingestion/dataset/train.csv")

# %%
null_report = df.isna().sum()/df.shape[0]
drop_column_names = null_report[null_report>0.3].index 
df.drop(list(drop_column_names),axis=1,inplace=True)

# %%
drop_column_names
# Out:
# Index(['ab_000', 'bk_000', 'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000',
#        'bq_000', 'br_000', 'cr_000'],
#       dtype='object')

# %%
# Out:
# class 0.0
# aa_000 0.0
# ab_000 0.7722970639032816
# ac_000 0.05951640759930915
# ad_000 0.2560621761658031
# ae_000 0.044317789291882556
# af_000 0.044317789291882556
# ag_000 0.010535405872193437
# ag_001 0.010535405872193437
# ag_002 0.010535405872193437
# ag_003 0.010535405872193437
# ag_004 0.010535405872193437
# ag_005 0.010535405872193437
# ag_006 0.010535405872193437
# ag_007 0.010535405872193437
# ag_008 0.010535405872193437
# ag_009 0.010535405872193437
# ah_000 0.010984455958549223
# ai_000 0.0107426597582038
# aj_000 0.0107426597582038
# ak_000 0.07844559585492228
# al_000 0.010880829015544042
# am_0 0.0107426597582038
# an_000 0.010880829015544042
# ao_000 0.009740932642487047
# ap_000 0.010880829015544042
# aq_000 0.009740932642487047
# ar_000 0.04825561312607945
# as_000 0.0107426597582038
# at_000 0.0107426597582038
# au_000 0.0107426597582038
# av_000 0.04435233160621762
# ax_000 0.04435233160621762
# ay_000 0.010535405872193437
# ay_001 0.010535405872193437
# ...

# %%
drop_column_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']
